# %%
import os
import cv2

# %%
data_dir = "../data/ImagesGoogleMapsOrchards"
dest_dir = '../data/contrast_eq/orchards'

# %%
# Set arbitrary gridsize for equalization window
gridsize = 8

# %%
for img_name in os.listdir(data_dir):
    img_data_path = os.path.join(data_dir, img_name)
    
    bgr = cv2.imread(img_data_path)
    lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(gridsize,gridsize))
    lab_planes[0] = clahe.apply(lab_planes[0])
    lab = cv2.merge(lab_planes)
    bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)

    img_dest_path = os.path.join(dest_dir, img_name)
    cv2.imwrite(img_dest_path, bgr)

# %%
# Show sample images, pre & post equalization
from PIL import Image
count = 0
for img_name in os.listdir(data_dir):
    if count % 500 == 0:
        Image.open(os.path.join(data_dir, img_name)).show()
        Image.open(os.path.join(dest_dir, img_name)).show()
    count += 1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B5B549150>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B585EA150>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B59C8B850>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B5C1C0B90>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B5A9DD7D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B59E66090>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B12327690>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F6B59CC2850>
